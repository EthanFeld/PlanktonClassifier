# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import zipfile

# %%
# Path to your zip file
zip_path = '/content/drive/MyDrive/Plankton/WHOI_raw_data/2010.zip' # CHANGE THIS

# Extract to the same directory as the zip file
extract_path = '/content/drive/MyDrive/Data/Plankton/WHOI_unzipped_data'

# Create the extraction directory if it doesn't exist
os.makedirs(extract_path, exist_ok=True)

# Unzip the file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)
print(f"Successfully extracted to {extract_path}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3050850082.py in <cell line: 0>()
#      10 # Unzip the file
#      11 with zipfile.ZipFile(zip_path, 'r') as zip_ref:
# ---> 12     zip_ref.extractall(extract_path)
#      13 print(f"Successfully extracted to {extract_path}")
#
# /usr/lib/python3.11/zipfile.py in extractall(self, path, members, pwd)
#    1700
#    1701         for zipinfo in members:
# -> 1702             self._extract_member(zipinfo, path, pwd)
#    1703
#    1704     @classmethod
#
# /usr/lib/python3.11/zipfile.py in _extract_member(self, member, targetpath, pwd)
#    1754
#    1755         with self.open(member, pwd=pwd) as source, \
# -> 1756              open(targetpath, "wb") as target:
#    1757             shutil.copyfileobj(source, target)
#    1758
#
# KeyboardInterrupt:
